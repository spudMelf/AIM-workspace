# %%
import librosa
import librosa.display
import IPython.display as ipd
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
meta = pd.read_csv("../../release_in_the_wild/meta.csv")

# %%
meta
# Out:
#             file                speaker      label
# 0          0.wav          Alec Guinness      spoof
# 1          1.wav          Alec Guinness      spoof
# 2          2.wav           Barack Obama      spoof
# 3          3.wav          Alec Guinness      spoof
# 4          4.wav   Christopher Hitchens  bona-fide
# ...          ...                    ...        ...
# 31774  31774.wav          Boris Johnson  bona-fide
# 31775  31775.wav           Donald Trump  bona-fide
# 31776  31776.wav           Donald Trump  bona-fide
# 31777  31777.wav             Alan Watts  bona-fide
# 31778  31778.wav  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
meta['label'][:1000].value_counts()
# Out:
# label
# bona-fide    633
# spoof        367
# Name: count, dtype: int64

# %%
path_prefix = '../../release_in_the_wild/'

# %%
def wav_to_melspectrogram(input_file, image_size=(224, 224)):
    # Load the audio file
    y, sr = librosa.load(input_file)

    # Compute the Mel spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)

    # Convert to decibels
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # Plot the Mel spectrogram without axis
    plt.figure(figsize=(image_size[0]/100, image_size[1]/100), dpi=100)  # Adjust figsize and dpi for desired image size
    librosa.display.specshow(log_mel_spectrogram, sr=sr, x_axis=None, y_axis=None)
    plt.axis('off')  # Turn off axis labels

    # Save the plot as a PNG image
    output_file = input_file[:-3] + 'png'
    plt.savefig(output_file, bbox_inches='tight', pad_inches=0)
    print(f"Saved mel spectrogram to {output_file} successfully")

    # Close the plot to free up memory
    plt.close()

# %%
wav_to_melspectrogram(path_prefix + meta['file'][0])
# Out:
# Saved mel spectrogram to ../../release_in_the_wild/0.png successfully

# %%
for path_suffix in meta['file']:
    wav_to_melspectrogram(path_prefix + path_suffix)
# Out:
# Saved mel spectrogram to ../../release_in_the_wild/0.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/1.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/2.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/3.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/4.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/5.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/6.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/7.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/8.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/9.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/10.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/11.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/12.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/13.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/14.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/15.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/16.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/17.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/18.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/19.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/20.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/21.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/22.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/23.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/24.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/25.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/26.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/27.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/28.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/29.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/30.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/31.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/32.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/33.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/34.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/35.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/36.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/37.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/38.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/39.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/40.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/41.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/42.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/43.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/44.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/45.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/46.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/47.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/48.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/49.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/50.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/51.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/52.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/53.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/54.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/55.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/56.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/57.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/58.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/59.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/60.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/61.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/62.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/63.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/64.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/65.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/66.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/67.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/68.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/69.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/70.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/71.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/72.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/73.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/74.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/75.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/76.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/77.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/78.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/79.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/80.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/81.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/82.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/83.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/84.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/85.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/86.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/87.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/88.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/89.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/90.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/91.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/92.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/93.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/94.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/95.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/96.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/97.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/98.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/99.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/100.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/101.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/102.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/103.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/104.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/105.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/106.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/107.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/108.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/109.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/110.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/111.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/112.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/113.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/114.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/115.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/116.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/117.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/118.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/119.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/120.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/121.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/122.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/123.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/124.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/125.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/126.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/127.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/128.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/129.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/130.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/131.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/132.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/133.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/134.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/135.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/136.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/137.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/138.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/139.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/140.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/141.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/142.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/143.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/144.png successfully
# Saved mel spectrogram to ../../release_in_the_wild/145.png successfully
# Saved mel spectrogram to ../../release_in_the_wild